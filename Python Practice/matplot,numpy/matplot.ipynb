# %%
# %matplotlib inline
import matplotlib.pyplot as plt
y = [1,2,3,4,5]
plt.plot(y)
plt.show()

# %%
import matplotlib.pyplot as plt
x = ['Mon', 'Tue', 'Wed', 'Thur', 'Fri', 'Sat', 'Sun']
y = [13, 16, 15, 18, 16, 17, 16]
#plt.plot(range(len(y)), y);
plt.plot(x, y);
plt.xlabel('Daily')
plt.ylabel('No. of Books Sold');

# %%
import matplotlib.pyplot as plt
x = ['Mon', 'Tue', 'Wed', 'Thur', 'Fri', 'Sat', 'Sun']
y1 = [13, 16, 15, 18, 16, 17, 16]
y2 = [17, 14, 17, 16, 15, 15, 14]
plt.plot(x, y1, label='Sold')
plt.plot(x, y2, label='On Shelves')
plt.xlabel('Daily')
plt.ylabel('No. of Books Sold')
plt.legend(loc="upper left")
plt.title('Le Petit Prince: Sold & Left')
# Out:
# Text(0.5, 1.0, 'Le Petit Prince: Sold & Left')

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]
plt.plot(x, y, 'bo')
plt.axis([0,6,0,30])
plt.show()

# %%
import numpy as np
points = np.array([[1,1], [1,2], [1,3], [2,1], [2,2], [2,3], [3,1], [3,2], [3,3]])
p = np.array([2.5, 2])
import matplotlib.pyplot as plt
plt.plot(points[:,0], points[:,1], "ro")
plt.plot(p[0], p[1], "bo")

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 5, 10)
y = x**2
plt.plot(x,y, "gs-", linewidth=1, markersize=3);

# %%
import matplotlib.pyplot as plt
import numpy as np
#x = np.linspace(0, 10, 20)
x = np.logspace(-1, 1, 20)
y1 = x**2.0
y2 = x**1.5
plt.plot(x,y1, "bo-", linewidth=1, markersize=3, label='First')
plt.plot(x,y2, "gs-", linewidth=1, markersize=3, label='Second')
plt.xlabel('x')
plt.xlabel('y')
plt.axis([-0.5, 10.5, -5, 105])
plt.legend(loc="upper left")
plt.savefig("mplot.pdf")

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.standard_normal(size=1000)
plt.hist(x, density=True)
# Out:
# (array([0.00448001, 0.02538673, 0.11946694, 0.27328063, 0.37632087,
#         0.35690749, 0.22848053, 0.08213352, 0.02240005, 0.00448001]),
#  array([-3.29723018, -2.62758887, -1.95794757, -1.28830626, -0.61866496,
#          0.05097635,  0.72061765,  1.39025896,  2.05990027,  2.72954157,
#          3.39918288]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.randn(1000)
plt.hist(x)
# Out:
# (array([  6.,  42., 130., 221., 245., 210., 107.,  31.,   6.,   2.]),
#  array([-2.95994722, -2.30490434, -1.64986146, -0.99481859, -0.33977571,
#          0.31526717,  0.97031005,  1.62535293,  2.28039581,  2.93543869,
#          3.59048157]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.rand(30)
y = np.random.rand(30)
colors = np.random.rand(30)
size = np.pi*(np.random.rand(30)*20)**2
plt.scatter(x,y,s=size, c=colors, marker='*', alpha=0.7)
plt.show()
